# %%
from __future__ import print_function
import keras
from keras import backend as K
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping
from keras.layers import Input
import tensorflow as tf
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py
import time
import os
import shutil
import multiprocessing
import EQTransformer.core.EqT_utils
from EQTransformer.core.trainer import _make_dir, _split, _make_callback, DataGenerator, _document_training
import datetime
from tqdm import tqdm
from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False


def user_trainer(input_hdf5=None,
            input_csv=None,
            output_name=None,                
            input_dimention=(6000, 3),
            cnn_blocks=5,
            lstm_blocks=2,
            padding='same',
            activation = 'relu',            
            drop_rate=0.1,
            shuffle=True, 
            label_type='gaussian',
            normalization_mode='std',
            augmentation=True,
            add_event_r=0.6,
            shift_event_r=0.99,
            add_noise_r=0.3, 
            drop_channel_r=0.5,
            add_gap_r=0.2,
            scale_amplitude_r=None,
            pre_emphasis=False,                
            loss_weights=[0.05, 0.40, 0.55],
            loss_types=['binary_crossentropy', 'binary_crossentropy', 'binary_crossentropy'],
            train_valid_test_split=[0.85, 0.05, 0.10],
            mode='generator',
            batch_size=200,
            epochs=200, 
            monitor='val_loss',
            patience=12,
            multi_gpu=False,
            number_of_gpus=4,
            gpuid=None,
            gpu_limit=None,
            use_multiprocessing=True):

    args = {
    "input_hdf5": input_hdf5,
    "input_csv": input_csv,
    "output_name": output_name,
    "input_dimention": input_dimention,
    "cnn_blocks": cnn_blocks,
    "lstm_blocks": lstm_blocks,
    "padding": padding,
    "activation": activation,
    "drop_rate": drop_rate,
    "shuffle": shuffle,
    "label_type": label_type,
    "normalization_mode": normalization_mode,
    "augmentation": augmentation,
    "add_event_r": add_event_r,
    "shift_event_r": shift_event_r,
    "add_noise_r": add_noise_r,
    "add_gap_r": add_gap_r,
    "drop_channel_r": drop_channel_r,
    "scale_amplitude_r": scale_amplitude_r,
    "pre_emphasis": pre_emphasis,
    "loss_weights": loss_weights,
    "loss_types": loss_types,
    "train_valid_test_split": train_valid_test_split,
    "mode": mode,
    "batch_size": batch_size,
    "epochs": epochs,
    "monitor": monitor,
    "patience": patience,           
    "multi_gpu": multi_gpu,
    "number_of_gpus": number_of_gpus,           
    "gpuid": gpuid,
    "gpu_limit": gpu_limit,
    "use_multiprocessing": use_multiprocessing
    }
                       
    def train(args):
        """ 
        
        Performs the training.
    
        Parameters
        ----------
        args : dic
            A dictionary object containing all of the input parameters. 

        Returns
        -------
        history: dic
            Training history.  
            
        model: 
            Trained model.
            
        start_training: datetime
            Training start time. 
            
        end_training: datetime
            Training end time. 
            
        save_dir: str
            Path to the output directory. 
            
        save_models: str
            Path to the folder for saveing the models.  
            
        training size: int
            Number of training samples.
            
        validation size: int
            Number of validation samples.  
            
        """    

        
        save_dir, save_models=_make_dir(args['output_name'])
        training, validation=_split(args, save_dir)
        callbacks=_make_callback(args, save_models)
        model=user_build_model(args)
        
        if args['gpuid']:           
            os.environ['CUDA_VISIBLE_DEVICES'] = '{}'.format(gpuid)
            tf.Session(config=tf.ConfigProto(log_device_placement=True))
            config = tf.ConfigProto()
            config.gpu_options.allow_growth = True
            config.gpu_options.per_process_gpu_memory_fraction = float(args['gpu_limit']) 
            K.tensorflow_backend.set_session(tf.Session(config=config))
            
        start_training = time.time()                  
            
        if args['mode'] == 'generator': 
            
            params_training = {'file_name': str(args['input_hdf5']), 
                              'dim': args['input_dimention'][0],
                              'batch_size': args['batch_size'],
                              'n_channels': args['input_dimention'][-1],
                              'shuffle': args['shuffle'],  
                              'norm_mode': args['normalization_mode'],
                              'label_type': args['label_type'],                          
                              'augmentation': args['augmentation'],
                              'add_event_r': args['add_event_r'], 
                              'add_gap_r': args['add_gap_r'],  
                              'shift_event_r': args['shift_event_r'],                            
                              'add_noise_r': args['add_noise_r'], 
                              'drop_channe_r': args['drop_channel_r'],
                              'scale_amplitude_r': args['scale_amplitude_r'],
                              'pre_emphasis': args['pre_emphasis']}    
                        
            params_validation = {'file_name': str(args['input_hdf5']),  
                                 'dim': args['input_dimention'][0],
                                 'batch_size': args['batch_size'],
                                 'n_channels': args['input_dimention'][-1],
                                 'shuffle': False,  
                                 'norm_mode': args['normalization_mode'],
                                 'augmentation': False}         

            training_generator = DataGenerator(training, **params_training)
            validation_generator = DataGenerator(validation, **params_validation) 

            print('Started training in generator mode ...') 
            history = model.fit_generator(generator=training_generator,
                                          validation_data=validation_generator,
                                          use_multiprocessing=args['use_multiprocessing'],
                                          workers=multiprocessing.cpu_count(),    
                                          callbacks=callbacks, 
                                          epochs=args['epochs'],
                                          class_weight={0: 0.11, 1: 0.89})
            
        elif args['mode'] == 'preload': 
            X, y1, y2, y3 = data_reader(list_IDs=training+validation, 
                                       file_name=str(args['input_hdf5']), 
                                       dim=args['input_dimention'][0], 
                                       n_channels=args['input_dimention'][-1], 
                                       norm_mode=args['normalization_mode'],
                                       augmentation=args['augmentation'],
                                       add_event_r=args['add_event_r'],
                                       add_gap_r=args['add_gap_r'], 
                                       shift_event_r=args['shift_event_r'], 
                                       add_noise_r=args['add_noise_r'],  
                                       drop_channe_r=args['drop_channel_r'],
                                       scale_amplitude_r=args['scale_amplitude_r'],
                                       pre_emphasis=args['pre_emphasis'])
             
            print('Started training in preload mode ...', flush=True) 
            history = model.fit({'input': X}, 
                                {'detector': y1, 'picker_P': y2, 'picker_S': y3}, 
                                epochs=args['epochs'],
                                validation_split=args['train_valid_test_split'][1],
                                batch_size=args['batch_size'], 
                                callbacks=callbacks,
                                class_weight={0: 0.11, 1: 0.89})            
        else:
            print('Please specify training_mode !', flush=True)
        end_training = time.time()  
        
        return history, model, start_training, end_training, save_dir, save_models, len(training), len(validation)
                  
    history, model, start_training, end_training, save_dir, save_models, training_size, validation_size=train(args)  
    _document_training(history, model, start_training, end_training, save_dir, save_models, training_size, validation_size, args)

# %%
def user_encoder(filter_number, filter_size, depth, drop_rate, ker_regul, bias_regul, activation, padding, inpC):
    ' Returns the encoder that is a combination of residual blocks and maxpooling.'        
    e = inpC
    e2 = inpC
    
    for dp in range(depth):
        
        e = keras.layers.SeparableConv1D(filter_number[dp], 
                   filter_size[dp], 
                   padding = padding, 
                   activation = activation,
                   kernel_regularizer = ker_regul,
                   bias_regularizer = bias_regul,
                   )(e)
        
        if(dp%3==0 and dp>0):
            e2 = Conv1D(filter_number[dp], 
                   filter_size[dp], 
                   padding = padding, 
                   activation = activation,
                   kernel_regularizer = ker_regul,
                   bias_regularizer = bias_regul,
                   )(e2)
            e = add([e, e2])
            
        
        e = MaxPooling1D(2, padding = padding)(e)
        e2 = MaxPooling1D(2, padding = padding)(e2)
        
    return(e) 


def user_decoder(filter_number, filter_size, depth, drop_rate, ker_regul, bias_regul, activation, padding, inpC):
    ' Returns the dencoder that is a combination of residual blocks and upsampling. '           
    d = inpC
    d2 = inpC
    
    for dp in range(depth):        
        d = UpSampling1D(2)(d) 
        d2 = UpSampling1D(2)(d2) 
        if dp == 3:
            d = Cropping1D(cropping=(1, 1))(d)
            d2 = Cropping1D(cropping=(1, 1))(d2)
        d = keras.layers.SeparableConv1D(filter_number[dp], 
                   filter_size[dp], 
                   padding = padding, 
                   activation = activation,
                   kernel_regularizer = ker_regul,
                   bias_regularizer = bias_regul,
                   )(d)
        
        if(dp%3==0 and dp>0):
            d2 = Conv1D(filter_number[dp], 
                   filter_size[dp], 
                   padding = padding, 
                   activation = activation,
                   kernel_regularizer = ker_regul,
                   bias_regularizer = bias_regul,
                   )(d2)
            d = add([d, d2])
        
        
    return(d)  

def nuser_decoder(filter_number, filter_size, depth, drop_rate, ker_regul, bias_regul, activation, padding, inpC):
    ' Returns the dencoder that is a combination of residual blocks and upsampling. '           
    d = inpC
    
    for dp in range(depth):        
        d = UpSampling1D(2)(d) 
        if dp == 3:
            d = Cropping1D(cropping=(1, 1))(d)
            
        d = Conv1D(filter_number[dp], 
                   filter_size[dp], 
                   padding = padding, 
                   activation = activation,
                   kernel_regularizer = ker_regul,
                   bias_regularizer = bias_regul,
                   )(d)
        
        
    return(d)

# %%
from __future__ import division, print_function
import numpy as np
import h5py
import matplotlib
matplotlib.use('agg')
from tqdm import tqdm
import keras
from keras import backend as K
from keras.layers import add, Activation, LSTM, Conv1D
from keras.layers import MaxPooling1D, UpSampling1D, Cropping1D, SpatialDropout1D, Bidirectional, BatchNormalization 
from keras.models import Model
from keras.utils import multi_gpu_model
from keras.optimizers import Adam
from obspy.signal.trigger import trigger_onset
import matplotlib
from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False
from EQTransformer.core.EqT_utils import _block_CNN_1, _block_BiLSTM, _transformer, _decoder, SeqSelfAttention, f1, _encoder,_lr_schedule

class user_cred2():


    def __init__(self,
                 nb_filters=[8, 16, 16, 32, 32, 96, 96, 128],
                 kernel_size=[11, 9, 7, 7, 5, 5, 3, 3],
                 padding='same',
                 activationf='relu',
                 endcoder_depth=7,
                 decoder_depth=7,
                 cnn_blocks=5,
                 BiLSTM_blocks=3,
                 drop_rate=0.1,
                 loss_weights=[0.2, 0.3, 0.5],
                 loss_types=['binary_crossentropy', 'binary_crossentropy', 'binary_crossentropy'],                                 
                 kernel_regularizer=keras.regularizers.l1(1e-4),
                 bias_regularizer=keras.regularizers.l1(1e-4),
                 multi_gpu=False, 
                 gpu_number=4, 
                 ):
        
        self.kernel_size = kernel_size
        self.nb_filters = nb_filters
        self.padding = padding
        self.activationf = activationf
        self.endcoder_depth= endcoder_depth
        self.decoder_depth= decoder_depth
        self.cnn_blocks= cnn_blocks
        self.BiLSTM_blocks= BiLSTM_blocks     
        self.drop_rate= drop_rate
        self.loss_weights= loss_weights  
        self.loss_types = loss_types       
        self.kernel_regularizer = kernel_regularizer     
        self.bias_regularizer = bias_regularizer 
        self.multi_gpu = multi_gpu
        self.gpu_number = gpu_number

        
    def __call__(self, inp):

        x = inp
        x = user_encoder(self.nb_filters, 
                    self.kernel_size, 
                    self.endcoder_depth, 
                    self.drop_rate, 
                    self.kernel_regularizer, 
                    self.bias_regularizer,
                    self.activationf, 
                    self.padding,
                    x)    
        #패딩한 데이터를 넘겨준다, encoder은 conv1d 7개짜리 sequence이다.
        
        for cb in range(self.cnn_blocks):
            if cb > 2:
                x = _block_CNN_1(self.nb_filters[6], 2, self.drop_rate, self.activationf, self.padding, x)
            else:
                x = _block_CNN_1(self.nb_filters[6], 3, self.drop_rate, self.activationf, self.padding, x)
        #cnn커널
        for bb in range(self.BiLSTM_blocks):
            x = _block_BiLSTM(self.nb_filters[1], self.drop_rate, self.padding, x)
        #lstm커널
            
        x, weightdD0 = _transformer(self.drop_rate, None, 'attentionD0', x)             
        encoded, weightdD = _transformer(self.drop_rate, None, 'attentionD', x)
        #transformer 함수는 
            
        decoder_D = nuser_decoder([i for i in reversed(self.nb_filters)], 
                             [i for i in reversed(self.kernel_size)], 
                             self.decoder_depth, 
                             self.drop_rate, 
                             self.kernel_regularizer, 
                             self.bias_regularizer,
                             self.activationf, 
                             self.padding,                             
                             encoded)
        #decoder은 7개짜리 upsampling sequence이다.
        
        d = Conv1D(1, 11, padding = self.padding, activation='sigmoid', name='detector')(decoder_D)


        PLSTM = LSTM(self.nb_filters[1], return_sequences=True, dropout=self.drop_rate, recurrent_dropout=self.drop_rate)(encoded)
        norm_layerP, weightdP = SeqSelfAttention(return_attention=True,
                                                 attention_width= 3,
                                                 name='attentionP')(PLSTM)
        
        decoder_P = user_decoder([i for i in reversed(self.nb_filters)], 
                            [i for i in reversed(self.kernel_size)], 
                            self.decoder_depth, 
                            self.drop_rate, 
                            self.kernel_regularizer, 
                            self.bias_regularizer,
                            self.activationf, 
                            self.padding,                            
                            norm_layerP)
        
        
        P = Conv1D(1, 11, padding = self.padding, activation='sigmoid', name='picker_P')(decoder_P)
        
        SLSTM = LSTM(self.nb_filters[1], return_sequences=True, dropout=self.drop_rate, recurrent_dropout=self.drop_rate)(encoded) 
        norm_layerS, weightdS = SeqSelfAttention(return_attention=True,
                                                 attention_width= 3,
                                                 name='attentionS')(SLSTM)
        
        
        decoder_S = nuser_decoder([i for i in reversed(self.nb_filters)], 
                            [i for i in reversed(self.kernel_size)],
                            self.decoder_depth, 
                            self.drop_rate, 
                            self.kernel_regularizer, 
                            self.bias_regularizer,
                            self.activationf, 
                            self.padding,                            
                            norm_layerS) 
        
        S = Conv1D(1, 11, padding = self.padding, activation='sigmoid', name='picker_S')(decoder_S)
        

        if self.multi_gpu == True:
            parallel_model = Model(inputs=inp, outputs=[d, P, S])
            model = multi_gpu_model(parallel_model, gpus=self.gpu_number)
        else:
            model = Model(inputs=inp, outputs=[d, P, S])

        model.compile(loss=self.loss_types, loss_weights=self.loss_weights,    
            optimizer=Adam(lr=_lr_schedule(0)), metrics=[f1])

        return model

# %%
def user_build_model(args): 

    inp = Input(shape=args['input_dimention'], name='input') 
    model = user_cred2(nb_filters=[8, 16, 16, 32, 32, 64, 32],
              kernel_size=[11, 9, 7, 7, 5, 5, 3],
              padding=args['padding'],
              activationf =args['activation'],
              cnn_blocks=args['cnn_blocks'],
              BiLSTM_blocks=args['lstm_blocks'],
              drop_rate=args['drop_rate'], 
              loss_weights=args['loss_weights'],
              loss_types=args['loss_types'],
              kernel_regularizer=keras.regularizers.l2(1e-6),
              bias_regularizer=keras.regularizers.l1(1e-4),
              multi_gpu=args['multi_gpu'], 
              gpu_number=args['number_of_gpus'],  
               )(inp)  
    model.summary()  
    return model

# %%
user_trainer(input_hdf5='mix_train_merge_modified.hdf5',
        input_csv='mix_train_merge_modified.csv',
        output_name='test_trainer',                
        cnn_blocks=5,
        lstm_blocks=2,
        padding='same',
        activation='relu',
        drop_rate=0.2,
        label_type='gaussian',
        add_event_r=0.6,
        add_gap_r=0.2,
        shift_event_r=0.9,
        add_noise_r=0.5, 
        mode='generator',
        loss_weights=[0.05, 0.40, 0.55],
        train_valid_test_split=[0.60, 0.20, 0.20],
        batch_size=20,
        epochs=10, 
        patience=10,
        gpuid=None,
        gpu_limit=None)
#지금은 half full
# Out:
# Learning rate:  0.001
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 6000, 3)      0
# __________________________________________________________________________________________________
# separable_conv1d_51 (SeparableC (None, 6000, 8)      65          input[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_43 (MaxPooling1D) (None, 3000, 8)      0           separable_conv1d_51[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_52 (SeparableC (None, 3000, 16)     216         max_pooling1d_43[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_45 (MaxPooling1D) (None, 1500, 16)     0           separable_conv1d_52[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_44 (MaxPooling1D) (None, 3000, 3)      0           input[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_53 (SeparableC (None, 1500, 16)     384         max_pooling1d_45[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_46 (MaxPooling1D) (None, 1500, 3)      0           max_pooling1d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_47 (MaxPooling1D) (None, 750, 16)      0           separable_conv1d_53[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_48 (MaxPooling1D) (None, 750, 3)       0           max_pooling1d_46[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_54 (SeparableC (None, 750, 32)      656         max_pooling1d_47[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 750, 32)      704         max_pooling1d_48[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 750, 32)      0           separable_conv1d_54[0][0]
#                                                                  conv1d_66[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_49 (MaxPooling1D) (None, 375, 32)      0           add_42[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_55 (SeparableC (None, 375, 32)      1216        max_pooling1d_49[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_51 (MaxPooling1D) (None, 188, 32)      0           separable_conv1d_55[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_50 (MaxPooling1D) (None, 375, 32)      0           conv1d_66[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_56 (SeparableC (None, 188, 64)      2272        max_pooling1d_51[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_52 (MaxPooling1D) (None, 188, 32)      0           max_pooling1d_50[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_53 (MaxPooling1D) (None, 94, 64)       0           separable_conv1d_56[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_54 (MaxPooling1D) (None, 94, 32)       0           max_pooling1d_52[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_57 (SeparableC (None, 94, 32)       2272        max_pooling1d_53[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 94, 32)       3104        max_pooling1d_54[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 94, 32)       0           separable_conv1d_57[0][0]
#                                                                  conv1d_67[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_55 (MaxPooling1D) (None, 47, 32)       0           add_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 47, 32)       128         max_pooling1d_55[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 47, 32)       0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 47, 8)        264         activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 47, 8)        32          conv1d_68[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 47, 8)        0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_16 (SpatialDr (None, 47, 8)        0           activation_47[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 47, 8)        200         spatial_dropout1d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 47, 8)        32          conv1d_69[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 47, 8)        0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 47, 32)       288         activation_48[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 47, 32)       0           max_pooling1d_55[0][0]
#                                                                  conv1d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 47, 32)       128         add_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 47, 32)       0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 47, 8)        264         activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 47, 8)        32          conv1d_71[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 47, 8)        0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_17 (SpatialDr (None, 47, 8)        0           activation_50[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 47, 8)        200         spatial_dropout1d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 47, 8)        32          conv1d_72[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 47, 8)        0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 47, 32)       288         activation_51[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 47, 32)       0           add_44[0][0]
#                                                                  conv1d_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 47, 32)       128         add_45[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 47, 32)       0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 47, 8)        264         activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 47, 8)        32          conv1d_74[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 47, 8)        0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_18 (SpatialDr (None, 47, 8)        0           activation_53[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 47, 8)        200         spatial_dropout1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 47, 8)        32          conv1d_75[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 47, 8)        0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 47, 32)       288         activation_54[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 47, 32)       0           add_45[0][0]
#                                                                  conv1d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 47, 32)       128         add_46[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 47, 32)       0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 47, 8)        264         activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 47, 8)        32          conv1d_77[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 47, 8)        0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_19 (SpatialDr (None, 47, 8)        0           activation_56[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 47, 8)        136         spatial_dropout1d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 47, 8)        32          conv1d_78[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 47, 8)        0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 47, 32)       288         activation_57[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 47, 32)       0           add_46[0][0]
#                                                                  conv1d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 47, 32)       128         add_47[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 47, 32)       0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 47, 8)        264         activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 47, 8)        32          conv1d_80[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 47, 8)        0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_20 (SpatialDr (None, 47, 8)        0           activation_59[0][0]
# __________________________________________________________________________________________________
# conv1d_81 (Conv1D)              (None, 47, 8)        136         spatial_dropout1d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 47, 8)        32          conv1d_81[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 47, 8)        0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv1d_82 (Conv1D)              (None, 47, 32)       288         activation_60[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 47, 32)       0           add_47[0][0]
#                                                                  conv1d_82[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 47, 32)       6272        add_48[0][0]
# __________________________________________________________________________________________________
# conv1d_83 (Conv1D)              (None, 47, 16)       528         bidirectional_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 47, 16)       64          conv1d_83[0][0]
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 47, 32)       4224        batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv1d_84 (Conv1D)              (None, 47, 16)       528         bidirectional_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 47, 16)       64          conv1d_84[0][0]
# __________________________________________________________________________________________________
# attentionD0 (SeqSelfAttention)  [(None, 47, 16), (No 1089        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 47, 16)       0           batch_normalization_68[0][0]
#                                                                  attentionD0[0][0]
# __________________________________________________________________________________________________
# layer_normalization_13 (LayerNo (None, 47, 16)       32          add_49[0][0]
# __________________________________________________________________________________________________
# feed_forward_7 (FeedForward)    (None, 47, 16)       4240        layer_normalization_13[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 47, 16)       0           layer_normalization_13[0][0]
#                                                                  feed_forward_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_14 (LayerNo (None, 47, 16)       32          add_50[0][0]
# __________________________________________________________________________________________________
# attentionD (SeqSelfAttention)   [(None, 47, 16), (No 1089        layer_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 47, 16)       0           layer_normalization_14[0][0]
#                                                                  attentionD[0][0]
# __________________________________________________________________________________________________
# layer_normalization_15 (LayerNo (None, 47, 16)       32          add_51[0][0]
# __________________________________________________________________________________________________
# feed_forward_8 (FeedForward)    (None, 47, 16)       4240        layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 47, 16)       0           layer_normalization_15[0][0]
#                                                                  feed_forward_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_16 (LayerNo (None, 47, 16)       32          add_52[0][0]
# __________________________________________________________________________________________________
# lstm_11 (LSTM)                  (None, 47, 16)       2112        layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# attentionP (SeqSelfAttention)   [(None, 47, 16), (No 1089        lstm_11[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_58 (UpSampling1D) (None, 94, 16)       0           attentionP[0][0]
# __________________________________________________________________________________________________
# lstm_12 (LSTM)                  (None, 47, 16)       2112        layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_58 (SeparableC (None, 94, 32)       592         up_sampling1d_58[0][0]
# __________________________________________________________________________________________________
# attentionS (SeqSelfAttention)   [(None, 47, 16), (No 1089        lstm_12[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_51 (UpSampling1D) (None, 94, 16)       0           layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_60 (UpSampling1D) (None, 188, 32)      0           separable_conv1d_58[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_72 (UpSampling1D) (None, 94, 16)       0           attentionS[0][0]
# __________________________________________________________________________________________________
# conv1d_85 (Conv1D)              (None, 94, 32)       1568        up_sampling1d_51[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_59 (SeparableC (None, 188, 64)      2272        up_sampling1d_60[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_59 (UpSampling1D) (None, 94, 16)       0           attentionP[0][0]
# __________________________________________________________________________________________________
# conv1d_94 (Conv1D)              (None, 94, 32)       1568        up_sampling1d_72[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_52 (UpSampling1D) (None, 188, 32)      0           conv1d_85[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_62 (UpSampling1D) (None, 376, 64)      0           separable_conv1d_59[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_61 (UpSampling1D) (None, 188, 16)      0           up_sampling1d_59[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_73 (UpSampling1D) (None, 188, 32)      0           conv1d_94[0][0]
# __________________________________________________________________________________________________
# conv1d_86 (Conv1D)              (None, 188, 64)      10304       up_sampling1d_52[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_60 (SeparableC (None, 376, 32)      2400        up_sampling1d_62[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_63 (UpSampling1D) (None, 376, 16)      0           up_sampling1d_61[0][0]
# __________________________________________________________________________________________________
# conv1d_95 (Conv1D)              (None, 188, 64)      10304       up_sampling1d_73[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_53 (UpSampling1D) (None, 376, 64)      0           conv1d_86[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_64 (UpSampling1D) (None, 752, 32)      0           separable_conv1d_60[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_65 (UpSampling1D) (None, 752, 16)      0           up_sampling1d_63[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_74 (UpSampling1D) (None, 376, 64)      0           conv1d_95[0][0]
# __________________________________________________________________________________________________
# conv1d_87 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_53[0][0]
# __________________________________________________________________________________________________
# cropping1d_12 (Cropping1D)      (None, 750, 32)      0           up_sampling1d_64[0][0]
# __________________________________________________________________________________________________
# cropping1d_13 (Cropping1D)      (None, 750, 16)      0           up_sampling1d_65[0][0]
# __________________________________________________________________________________________________
# conv1d_96 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_74[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_54 (UpSampling1D) (None, 752, 32)      0           conv1d_87[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_61 (SeparableC (None, 750, 32)      1280        cropping1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_92 (Conv1D)              (None, 750, 32)      3616        cropping1d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_75 (UpSampling1D) (None, 752, 32)      0           conv1d_96[0][0]
# __________________________________________________________________________________________________
# cropping1d_11 (Cropping1D)      (None, 750, 32)      0           up_sampling1d_54[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 750, 32)      0           separable_conv1d_61[0][0]
#                                                                  conv1d_92[0][0]
# __________________________________________________________________________________________________
# cropping1d_14 (Cropping1D)      (None, 750, 32)      0           up_sampling1d_75[0][0]
# __________________________________________________________________________________________________
# conv1d_88 (Conv1D)              (None, 750, 32)      7200        cropping1d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_66 (UpSampling1D) (None, 1500, 32)     0           add_53[0][0]
# __________________________________________________________________________________________________
# conv1d_97 (Conv1D)              (None, 750, 32)      7200        cropping1d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_55 (UpSampling1D) (None, 1500, 32)     0           conv1d_88[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_62 (SeparableC (None, 1500, 16)     752         up_sampling1d_66[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_76 (UpSampling1D) (None, 1500, 32)     0           conv1d_97[0][0]
# __________________________________________________________________________________________________
# conv1d_89 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_55[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_68 (UpSampling1D) (None, 3000, 16)     0           separable_conv1d_62[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_67 (UpSampling1D) (None, 1500, 32)     0           conv1d_92[0][0]
# __________________________________________________________________________________________________
# conv1d_98 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_76[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_56 (UpSampling1D) (None, 3000, 16)     0           conv1d_89[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_63 (SeparableC (None, 3000, 16)     416         up_sampling1d_68[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_69 (UpSampling1D) (None, 3000, 32)     0           up_sampling1d_67[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_77 (UpSampling1D) (None, 3000, 16)     0           conv1d_98[0][0]
# __________________________________________________________________________________________________
# conv1d_90 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_56[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_70 (UpSampling1D) (None, 6000, 16)     0           separable_conv1d_63[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_71 (UpSampling1D) (None, 6000, 32)     0           up_sampling1d_69[0][0]
# __________________________________________________________________________________________________
# conv1d_99 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_77[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_57 (UpSampling1D) (None, 6000, 16)     0           conv1d_90[0][0]
# __________________________________________________________________________________________________
# separable_conv1d_64 (SeparableC (None, 6000, 8)      312         up_sampling1d_70[0][0]
# __________________________________________________________________________________________________
# conv1d_93 (Conv1D)              (None, 6000, 8)      2824        up_sampling1d_71[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_78 (UpSampling1D) (None, 6000, 16)     0           conv1d_99[0][0]
# __________________________________________________________________________________________________
# conv1d_91 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_57[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 6000, 8)      0           separable_conv1d_64[0][0]
#                                                                  conv1d_93[0][0]
# __________________________________________________________________________________________________
# conv1d_100 (Conv1D)             (None, 6000, 8)      1416        up_sampling1d_78[0][0]
# __________________________________________________________________________________________________
# detector (Conv1D)               (None, 6000, 1)      89          conv1d_91[0][0]
# __________________________________________________________________________________________________
# picker_P (Conv1D)               (None, 6000, 1)      89          add_54[0][0]
# __________________________________________________________________________________________________
# picker_S (Conv1D)               (None, 6000, 1)      89          conv1d_100[0][0]
# ==================================================================================================
# Total params: 132,440
# Trainable params: 131,896
# Non-trainable params: 544
# __________________________________________________________________________________________________
# Started training in generator mode ...
# Epoch 1/10
# Learning rate:  0.001
# 6000/6000 [==============================] - 7001s 1s/step - loss: 0.0141 - detector_loss: 0.0824 - picker_P_loss: 0.0101 - picker_S_loss: 0.0102 - detector_f1: 0.7118 - picker_P_f1: 0.0143 - picker_S_f1: 6.3041e-05 - val_loss: 0.0058 - val_detector_loss: 0.0231 - val_picker_P_loss: 0.0036 - val_picker_S_loss: 0.0045 - val_detector_f1: 0.9270 - val_picker_P_f1: 0.1980 - val_picker_S_f1: 0.0061
#
# Epoch 00001: val_loss improved from inf to 0.00580, saving model to C:\Users\JeoungSeoungHeong\EQ\EQTransformer_master\test_trainer_outputs\models\test_trainer_001.h5
# Epoch 2/10
# Learning rate:  0.001
# 6000/6000 [==============================] - 6789s 1s/step - loss: 0.0077 - detector_loss: 0.0382 - picker_P_loss: 0.0059 - picker_S_loss: 0.0059 - detector_f1: 0.8837 - picker_P_f1: 0.2708 - picker_S_f1: 0.1099 - val_loss: 0.0043 - val_detector_loss: 0.0136 - val_picker_P_loss: 0.0031 - val_picker_S_loss: 0.0038 - val_detector_f1: 0.9542 - val_picker_P_f1: 0.5265 - val_picker_S_f1: 0.2412
#
# Epoch 00002: val_loss improved from 0.00580 to 0.00428, saving model to C:\Users\JeoungSeoungHeong\EQ\EQTransformer_master\test_trainer_outputs\models\test_trainer_002.h5
# Epoch 3/10
# Learning rate:  0.001
# 6000/6000 [==============================] - 6810s 1s/step - loss: 0.0068 - detector_loss: 0.0306 - picker_P_loss: 0.0053 - picker_S_loss: 0.0054 - detector_f1: 0.9070 - picker_P_f1: 0.3836 - picker_S_f1: 0.2384 - val_loss: 0.0045 - val_detector_loss: 0.0125 - val_picker_P_loss: 0.0029 - val_picker_S_loss: 0.0036 - val_detector_f1: 0.9575 - val_picker_P_f1: 0.5213 - val_picker_S_f1: 0.3071
#
# Epoch 00003: val_loss did not improve from 0.00428
# Epoch 4/10
# Learning rate:  0.001
# 6000/6000 [==============================] - 7182s 1s/step - loss: 0.0063 - detector_loss: 0.0270 - picker_P_loss: 0.0049 - picker_S_loss: 0.0051 - detector_f1: 0.9176 - picker_P_f1: 0.4317 - picker_S_f1: 0.2848 - val_loss: 0.0028 - val_detector_loss: 0.0095 - val_picker_P_loss: 0.0024 - val_picker_S_loss: 0.0034 - val_detector_f1: 0.9650 - val_picker_P_f1: 0.6262 - val_picker_S_f1: 0.4128
#
# Epoch 00004: val_loss improved from 0.00428 to 0.00279, saving model to C:\Users\JeoungSeoungHeong\EQ\EQTransformer_master\test_trainer_outputs\models\test_trainer_004.h5
# Epoch 5/10
# Learning rate:  0.001
# 6000/6000 [==============================] - 6942s 1s/step - loss: 0.0060 - detector_loss: 0.0252 - picker_P_loss: 0.0048 - picker_S_loss: 0.0050 - detector_f1: 0.9234 - picker_P_f1: 0.4555 - picker_S_f1: 0.3102 - val_loss: 0.0036 - val_detector_loss: 0.0087 - val_picker_P_loss: 0.0023 - val_picker_S_loss: 0.0035 - val_detector_f1: 0.9686 - val_picker_P_f1: 0.6538 - val_picker_S_f1: 0.3820
#
# Epoch 00005: val_loss did not improve from 0.00279
# Epoch 6/10
# Learning rate:  0.001
# 6000/6000 [==============================] - 7486s 1s/step - loss: 0.0058 - detector_loss: 0.0240 - picker_P_loss: 0.0046 - picker_S_loss: 0.0049 - detector_f1: 0.9263 - picker_P_f1: 0.4712 - picker_S_f1: 0.3274 - val_loss: 0.0034 - val_detector_loss: 0.0100 - val_picker_P_loss: 0.0022 - val_picker_S_loss: 0.0034 - val_detector_f1: 0.9682 - val_picker_P_f1: 0.6652 - val_picker_S_f1: 0.4103
#
# Epoch 00006: val_loss did not improve from 0.00279
# Epoch 7/10
# Learning rate:  0.001
# 6000/6000 [==============================] - 7386s 1s/step - loss: 0.0057 - detector_loss: 0.0225 - picker_P_loss: 0.0045 - picker_S_loss: 0.0048 - detector_f1: 0.9290 - picker_P_f1: 0.4824 - picker_S_f1: 0.3385 - val_loss: 0.0033 - val_detector_loss: 0.0081 - val_picker_P_loss: 0.0021 - val_picker_S_loss: 0.0033 - val_detector_f1: 0.9713 - val_picker_P_f1: 0.6606 - val_picker_S_f1: 0.4274
#
# Epoch 00007: val_loss did not improve from 0.00279
# Epoch 8/10
# Learning rate:  0.001
# 6000/6000 [==============================] - 6839s 1s/step - loss: 0.0056 - detector_loss: 0.0217 - picker_P_loss: 0.0044 - picker_S_loss: 0.0047 - detector_f1: 0.9321 - picker_P_f1: 0.4894 - picker_S_f1: 0.3511 - val_loss: 0.0025 - val_detector_loss: 0.0065 - val_picker_P_loss: 0.0020 - val_picker_S_loss: 0.0032 - val_detector_f1: 0.9764 - val_picker_P_f1: 0.6644 - val_picker_S_f1: 0.4429
#
# Epoch 00008: val_loss improved from 0.00279 to 0.00253, saving model to C:\Users\JeoungSeoungHeong\EQ\EQTransformer_master\test_trainer_outputs\models\test_trainer_008.h5
# Epoch 9/10
# Learning rate:  0.001
# 6000/6000 [==============================] - 6755s 1s/step - loss: 0.0055 - detector_loss: 0.0216 - picker_P_loss: 0.0044 - picker_S_loss: 0.0047 - detector_f1: 0.9339 - picker_P_f1: 0.4928 - picker_S_f1: 0.3584 - val_loss: 0.0023 - val_detector_loss: 0.0066 - val_picker_P_loss: 0.0020 - val_picker_S_loss: 0.0032 - val_detector_f1: 0.9759 - val_picker_P_f1: 0.6799 - val_picker_S_f1: 0.4485
#
# Epoch 00009: val_loss improved from 0.00253 to 0.00230, saving model to C:\Users\JeoungSeoungHeong\EQ\EQTransformer_master\test_trainer_outputs\models\test_trainer_009.h5
# Epoch 10/10
# Learning rate:  0.001
# 6000/6000 [==============================] - 6668s 1s/step - loss: 0.0055 - detector_loss: 0.0212 - picker_P_loss: 0.0043 - picker_S_loss: 0.0047 - detector_f1: 0.9350 - picker_P_f1: 0.4997 - picker_S_f1: 0.3618 - val_loss: 0.0025 - val_detector_loss: 0.0079 - val_picker_P_loss: 0.0020 - val_picker_S_loss: 0.0032 - val_detector_f1: 0.9729 - val_picker_P_f1: 0.6801 - val_picker_S_f1: 0.4788
#
# Epoch 00010: val_loss did not improve from 0.00230

# %%
import sys
from EQTransformer.core.mytester import tester
tester(input_hdf5='mix_train_merge_modified.hdf5',
       input_testset='test_trainer_outputs/test.npy',
       input_model='test_trainer_outputs/final_model.h5',
       output_name='test_tester',
       detection_threshold=0.50,                
       P_threshold=0.3,
       S_threshold=0.3, 
       number_of_plots=3,
       estimate_uncertainty=True, 
       number_of_sampling=2,
       input_dimention=(6000, 3),
       normalization_mode='std',
       mode='generator',
       batch_size=10,
       gpuid=None,
       gpu_limit=None)
# Out:
# Loading the model ...!
# Loading is complete!!!
# Testing ...
# Writting results into: " test_tester_outputs "
#   0%|                                                                                         | 0/2000 [00:00<?, ?it/s]
#   0%|                                                                               | 2/2000 [00:04<1:21:38,  2.45s/it]
#   0%|                                                                               | 3/2000 [00:05<1:03:35,  1.91s/it]
#   0%|▏                                                                                | 4/2000 [00:06<50:52,  1.53s/it]
#   0%|▏                                                                                | 5/2000 [00:06<42:01,  1.26s/it]
#   0%|▏                                                                                | 6/2000 [00:07<35:48,  1.08s/it]
#   0%|▎                                                                                | 7/2000 [00:08<31:27,  1.06it/s]
#   0%|▎                                                                                | 8/2000 [00:08<28:26,  1.17it/s]
#   0%|▎                                                                                | 9/2000 [00:09<26:17,  1.26it/s]
#   0%|▍                                                                               | 10/2000 [00:10<24:48,  1.34it/s]
#   1%|▍                                                                               | 11/2000 [00:10<23:44,  1.40it/s]
#   1%|▍                                                                               | 12/2000 [00:11<22:59,  1.44it/s]
#   1%|▌                                                                               | 13/2000 [00:11<22:28,  1.47it/s]
#   1%|▌                                                                               | 14/2000 [00:12<22:07,  1.50it/s]
#   1%|▌                                                                               | 15/2000 [00:13<21:51,  1.51it/s]
#   1%|▋                                                                               | 16/2000 [00:13<21:42,  1.52it/s]
#   1%|▋                                                                               | 17/2000 [00:14<21:35,  1.53it/s]
#   1%|▋                                                                               | 18/2000 [00:15<21:27,  1.54it/s]
#   1%|▊                                                                               | 19/2000 [00:15<21:24,  1.54it/s]
#   1%|▊                                                                               | 20/2000 [00:16<21:19,  1.55it/s]
#   1%|▊                                                                               | 21/2000 [00:17<21:17,  1.55it/s]
#   1%|▉                                                                               | 22/2000 [00:17<21:15,  1.55it/s]
#   1%|▉                                                                               | 23/2000 [00:18<21:13,  1.55it/s]
#   1%|▉                                                                               | 24/2000 [00:19<21:13,  1.55it/s]
#   1%|█                                                                               | 25/2000 [00:19<21:12,  1.55it/s]
#   1%|█                                                                               | 26/2000 [00:20<21:11,  1.55it/s]
#   1%|█                                                                               | 27/2000 [00:20<21:08,  1.56it/s]
