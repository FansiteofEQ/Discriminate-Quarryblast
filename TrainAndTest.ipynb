# %%
from EQTransformer.core.trainer import trainer
trainer(input_hdf5='../stead/merge_modified.hdf5',
        input_csv='../stead/mini_merged.csv',
        output_name='test_trainer',                
        cnn_blocks=5,
        lstm_blocks=2,
        padding='same',
        activation='relu',
        label_type='gaussian',
        mode='generator',
        train_valid_test_split=[0.80, 0.10, 0.10],
        batch_size=20,
        epochs=10, 
        patience=2,
        gpuid=None,
        gpu_limit=None)
# Out:
# Using TensorFlow backend.
# Learning rate:  0.002
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              (None, 6000, 3)      0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 8)      272         input[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 3000, 8)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 3000, 16)     1168        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from EQTransformer.core.mytester import tester
tester(input_hdf5='../stead/merge_modified.hdf5',
       input_testset='test_trainer_outputs/test.npy',
       input_model='test_trainer_outputs/final_model.h5',
       output_name='test_tester',
       detection_threshold=0.50,                
       P_threshold=0.3,
       S_threshold=0.3, 
       number_of_plots=3,
       estimate_uncertainty=False, 
       number_of_sampling=2,
       input_dimention=(6000, 3),
       normalization_mode='std',
       mode='generator',
       batch_size=10,
       gpuid=None,
       gpu_limit=None)
# Out:
# Loading the model ...!
# Loading is complete!!!
# Testing ...
# Writting results into: " test_tester_outputs "
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [11:07<00:00,  1.51it/s]
